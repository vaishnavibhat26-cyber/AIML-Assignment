# %%
## Decision Tree on Paper
Decision Tree: Should I Play Outside?
Use this tree:

                    Weather?
                 /     |      \
             Sunny   Rainy   Cloudy
               |       |        |
          Humidity?    No      Yes
           /    \
       High    Normal
        |         |
       No        Yes
Explanation
If the weather is rainy, then do not play outside.
If the weather is cloudy, then play outside.
If the weather is sunny, check humidity:
If humidity is high, do not play.
If humidity is normal, play.
    s
OR
    
Should I Play Outside?
Weather = Sunny
Humidity = High → No
Humidity = Normal → Yes
Weather = Rainy → No
Weather = Cloudy → Yes

Final conclusion : This decision tree helps in making a simple prediction based on weather conditions.
