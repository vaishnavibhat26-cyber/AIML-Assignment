# %%
##  AI Around Me
 1. Google Maps: Uses ML to analyze traffic data and predict fastest routes based on real-time conditions.
 2. YouTube Recommendations : ML suggests videos based on your watch history and user behavior patterns.
 3. Instagram Feed: Shows posts using ML by learning your likes, comments, and interactions.
 4. Voice Assistants (Siri / Google Assistant) : Uses speech recognition and NLP models to understand and respond to voice commands.
 5. Gmail Spam Filter : ML detects spam emails by learning patterns from previous spam messages.
 6. Netflix Recommendations : Suggests movies using ML based on your viewing history and similar users.
 7. Online Shopping (Amazon / Flipkart): Recommends products using ML by analyzing your searches and purchase history.
 8. Face Unlock (Mobile) : Uses ML-based facial recognition to identify and unlock your device.
 9. Google Search : ML ranks search results based on relevance, user behavior, and keywords.
 10. Chatbots (Customer Support / ChatGPT) : Uses NLP and ML models to understand questions and generate responses.
