# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\vaish\anaconda3\lib\site-packages (from opencv-python) (2.3.5)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    ---------------------------------------- 0.3/40.2 MB ? eta -:--:--
#    - -------------------------------------- 1.3/40.2 MB 6.4 MB/s eta 0:00:07
#    -- ------------------------------------- 2.6/40.2 MB 5.5 MB/s eta 0:00:07
#    --- ------------------------------------ 3.7/40.2 MB 5.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 4.7/40.2 MB 5.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 6.0/40.2 MB 5.5 MB/s eta 0:00:07
#    ------- -------------------------------- 7.1/40.2 MB 5.5 MB/s eta 0:00:07
#    ------- -------------------------------- 7.9/40.2 MB 5.5 MB/s eta 0:00:06
#    --------- ------------------------------ 9.4/40.2 MB 5.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.5/40.2 MB 5.5 MB/s eta 0:00:06
#    ----------- ---------------------------- 11.3/40.2 MB 5.5 MB/s eta 0:00:06
#    ------------ --------------------------- 12.8/40.2 MB 5.4 MB/s eta 0:00:06
#    ------------- -------------------------- 13.9/40.2 MB 5.5 MB/s eta 0:00:05
#    -------------- ------------------------- 14.9/40.2 MB 5.4 MB/s eta 0:00:05
#    --------------- ------------------------ 16.0/40.2 MB 5.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 17.3/40.2 MB 5.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 18.1/40.2 MB 5.3 MB/s eta 0:00:05
#    ------------------- -------------------- 19.1/40.2 MB 5.3 MB/s eta 0:00:04
#    ------------------- -------------------- 19.9/40.2 MB 5.2 MB/s eta 0:00:04
#    -------------------- ------------------- 21.0/40.2 MB 5.2 MB/s eta 0:00:04
#    --------------------- ------------------ 21.5/40.2 MB 5.1 MB/s eta 0:00:04
#    ---------------------- ----------------- 22.3/40.2 MB 5.0 MB/s eta 0:00:04
#    ---------------------- ----------------- 23.1/40.2 MB 5.0 MB/s eta 0:00:04
#    ----------------------- ---------------- 23.3/40.2 MB 4.9 MB/s eta 0:00:04
#    ----------------------- ---------------- 24.1/40.2 MB 4.7 MB/s eta 0:00:04
#    ------------------------ --------------- 24.6/40.2 MB 4.7 MB/s eta 0:00:04
#    ------------------------ --------------- 24.9/40.2 MB 4.6 MB/s eta 0:00:04
#    ------------------------- -------------- 25.4/40.2 MB 4.5 MB/s eta 0:00:04
#    ------------------------- -------------- 26.0/40.2 MB 4.4 MB/s eta 0:00:04
#    -------------------------- ------------- 26.2/40.2 MB 4.3 MB/s eta 0:00:04
#    -------------------------- ------------- 26.7/40.2 MB 4.2 MB/s eta 0:00:04
#    --------------------------- ------------ 27.3/40.2 MB 4.1 MB/s eta 0:00:04
#    --------------------------- ------------ 27.5/40.2 MB 4.1 MB/s eta 0:00:04
#    --------------------------- ------------ 28.0/40.2 MB 4.0 MB/s eta 0:00:04
#    ---------------------------- ----------- 28.6/40.2 MB 4.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 29.1/40.2 MB 4.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 29.6/40.2 MB 3.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 30.1/40.2 MB 3.9 MB/s eta 0:00:03
#    ------------------------------ --------- 30.7/40.2 MB 3.8 MB/s eta 0:00:03
#    ------------------------------- -------- 31.2/40.2 MB 3.8 MB/s eta 0:00:03
#    ------------------------------- -------- 31.7/40.2 MB 3.7 MB/s eta 0:00:03
#    ------------------------------- -------- 32.0/40.2 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 32.5/40.2 MB 3.7 MB/s eta 0:00:03
#    -------------------------------- ------- 33.0/40.2 MB 3.7 MB/s eta 0:00:02
#    --------------------------------- ------ 33.6/40.2 MB 3.6 MB/s eta 0:00:02
#    --------------------------------- ------ 34.1/40.2 MB 3.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.6/40.2 MB 3.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.9/40.2 MB 3.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 35.4/40.2 MB 3.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 35.9/40.2 MB 3.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 36.2/40.2 MB 3.5 MB/s eta 0:00:02
#    ------------------------------------ --- 36.7/40.2 MB 3.4 MB/s eta 0:00:02
#    ------------------------------------- -- 37.2/40.2 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 37.7/40.2 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 38.0/40.2 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 38.5/40.2 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 39.1/40.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  39.6/40.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  40.1/40.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 3.2 MB/s  0:00:12
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.13.0

# %%
## Image as Numbers
import cv2
import matplotlib.pyplot as plt

image = cv2.imread("sample.jpeg")

if image is None:
    print("Image not found. Please check the file path.")
else:
    print("Image Shape:", image.shape)
    print("Image Size:", image.size)
    print("Data Type:", image.dtype)

    print("\nPixel Values (first 5x5 area):")
    print(image[:5, :5])

    b, g, r = cv2.split(image)

    print("\nBlue Channel Shape:", b.shape)
    print("Green Channel Shape:", g.shape)
    print("Red Channel Shape:", r.shape)

    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image_rgb)
    plt.title("Original Image")
    plt.axis("off")
    plt.show()
# Out:
# Image Shape: (837, 408, 3)
# Image Size: 1024488
# Data Type: uint8
#
# Pixel Values (first 5x5 area):
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
#
# Blue Channel Shape: (837, 408)
# Green Channel Shape: (837, 408)
# Red Channel Shape: (837, 408)
