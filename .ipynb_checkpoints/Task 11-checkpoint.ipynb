# %%
data = {
"text": [
"I love this movie",
"This is amazing",
"Worst experience ever",
"I hate this",
"Very good service",
"Not satisfied",
"Excellent quality",
"Bad product",
"It is okay",
"Fantastic movie",
"Terrible acting",
"I enjoyed it",
"Not good",
"Superb performance",
"Awful film",
"Great story",
"Poor direction",
"Average movie",
"Loved it",
"Horrible experience"
],

"label": [
"positive","positive","negative","negative","positive",
"negative","positive","negative","neutral","positive",
"negative","positive","negative","positive","negative",
"positive","negative","neutral","positive","negative"
]
}

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df["text"], df["label"], test_size=0.3, random_state=42
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_tfidf, y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test_tfidf)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.16666666666666666

# %%
print("Dataset:")
display(df)
# Out:
# Dataset:
#                      text     label
# 0       I love this movie  positive
# 1         This is amazing  positive
# 2   Worst experience ever  negative
# 3             I hate this  negative
# 4       Very good service  positive
# 5           Not satisfied  negative
# 6       Excellent quality  positive
# 7             Bad product  negative
# 8              It is okay   neutral
# 9         Fantastic movie  positive
# 10        Terrible acting  negative
# 11           I enjoyed it  positive
# 12               Not good  negative
# 13     Superb performance  positive
# 14             Awful film  negative
# 15            Great story  positive
# 16         Poor direction  negative
# 17          Average movie   neutral
# 18               Loved it  positive
# 19    Horrible experience  negative

# %%
tfidf_df = pd.DataFrame(
    X_train_tfidf.toarray(),
    columns=tfidf.get_feature_names_out()
)

print("\nTF-IDF Matrix:")
display(tfidf_df)
# Out:
# TF-IDF Matrix:
#       acting     awful       bad  direction   enjoyed     ever  excellent  \
# 0   0.000000  0.000000  0.000000   0.000000  0.756121  0.00000   0.000000
# 1   0.000000  0.000000  0.000000   0.000000  0.000000  0.00000   0.000000
# 2   0.000000  0.000000  0.000000   0.000000  0.000000  0.00000   0.000000
# 3   0.000000  0.000000  0.000000   0.707107  0.000000  0.00000   0.000000
# 4   0.000000  0.000000  0.000000   0.000000  0.000000  0.00000   0.000000
# 5   0.000000  0.000000  0.000000   0.000000  0.000000  0.60312   0.000000
# 6   0.000000  0.000000  0.000000   0.000000  0.000000  0.00000   0.000000
# 7   0.000000  0.000000  0.000000   0.000000  0.000000  0.00000   0.000000
# 8   0.000000  0.000000  0.000000   0.000000  0.000000  0.00000   0.000000
# 9   0.000000  0.000000  0.000000   0.000000  0.000000  0.00000   0.000000
# 10  0.000000  0.000000  0.707107   0.000000  0.000000  0.00000   0.000000
# 11  0.707107  0.000000  0.000000   0.000000  0.000000  0.00000   0.000000
# 12  0.000000  0.707107  0.000000   0.000000  0.000000  0.00000   0.000000
# 13  0.000000  0.000000  0.000000   0.000000  0.000000  0.00000   0.707107
#
#     experience  fantastic      film  ...  performance      poor   product  \
# 0     0.000000   0.000000  0.000000  ...     0.000000  0.000000  0.000000
# 1     0.000000   0.000000  0.000000  ...     0.000000  0.000000  0.000000
# 2     0.000000   0.000000  0.000000  ...     0.000000  0.000000  0.000000
# 3     0.000000   0.000000  0.000000  ...     0.000000  0.707107  0.000000
# 4     0.000000   0.000000  0.000000  ...     0.707107  0.000000  0.000000
# 5     0.522008   0.000000  0.000000  ...     0.000000  0.000000  0.000000
# 6     0.000000   0.707107  0.000000  ...     0.000000  0.000000  0.000000
# 7     0.654432   0.000000  0.000000  ...     0.000000  0.000000  0.000000
# 8     0.000000   0.000000  0.000000  ...     0.000000  0.000000  0.000000
# 9     0.000000   0.000000  0.000000  ...     0.000000  0.000000  0.000000
# 10    0.000000   0.000000  0.000000  ...     0.000000  0.000000  0.707107
# 11    0.000000   0.000000  0.000000  ...     0.000000  0.000000  0.000000
# 12    0.000000   0.000000  0.707107  ...     0.000000  0.000000  0.000000
# 13    0.000000   0.000000  0.000000  ...     0.000000  0.000000  0.000000
#
#      quality  service    superb  terrible      this     very    worst
# 0   0.000000  0.00000  0.000000  0.000000  0.000000  0.00000  0.00000
# 1   0.000000  0.00000  0.000000  0.000000  0.707107  0.00000  0.00000
# 2   0.000000  0.00000  0.000000  0.000000  0.000000  0.00000  0.00000
# 3   0.000000  0.00000  0.000000  0.000000  0.000000  0.00000  0.00000
# 4   0.000000  0.00000  0.707107  0.000000  0.000000  0.00000  0.00000
# 5   0.000000  0.00000  0.000000  0.000000  0.000000  0.00000  0.60312
# 6   0.000000  0.00000  0.000000  0.000000  0.000000  0.00000  0.00000
# 7   0.000000  0.00000  0.000000  0.000000  0.000000  0.00000  0.00000
# 8   0.000000  0.60312  0.000000  0.000000  0.000000  0.60312  0.00000
# 9   0.000000  0.00000  0.000000  0.000000  0.000000  0.00000  0.00000
# 10  0.000000  0.00000  0.000000  0.000000  0.000000  0.00000  0.00000
# 11  0.000000  0.00000  0.000000  0.707107  0.000000  0.00000  0.00000
# 12  0.000000  0.00000  0.000000  0.000000  0.000000  0.00000  0.00000
# 13  0.707107  0.00000  0.000000  0.000000  0.000000  0.00000  0.00000
#
# [14 rows x 27 columns]

# %%
results_df = pd.DataFrame({
    "Text": X_test.values,
    "Actual": y_test.values,
    "Predicted": y_pred
})

print("\nPrediction Results:")
display(results_df)
# Out:
# Prediction Results:
#                 Text    Actual Predicted
# 0  I love this movie  positive  negative
# 1      Average movie   neutral  positive
# 2        Great story  positive  negative
# 3    This is amazing  positive  negative
# 4         It is okay   neutral  positive
# 5      Not satisfied  negative  negative

# %%
acc_df = pd.DataFrame({
    "Metric": ["Accuracy"],
    "Value": [accuracy_score(y_test, y_pred)]
})

print("\nAccuracy:")
display(acc_df)
# Out:
# Accuracy:
#      Metric     Value
# 0  Accuracy  0.166667
