# %%
## Word Importance Explorer
import warnings
warnings.filterwarnings('ignore')
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
documents = [
    "Artificial intelligence helps machines learn from data and perform smart tasks.",
    "Machine learning is a part of artificial intelligence that uses algorithms to learn patterns.",
    "Natural language processing helps computers understand human language and text.",
    "Deep learning uses neural networks for image recognition, speech recognition, and prediction.",
    "Data science combines statistics, programming, and machine learning to analyze data."
]

# %%
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(documents)

# %%
feature_names = vectorizer.get_feature_names_out()

# %%
for i in range(len(documents)):
    row = tfidf_matrix[i].toarray().flatten()
    top_indices = row.argsort()[-5:][::-1]
    
    print(f"\nDocument {i+1}:")
    print(documents[i])
    print("Top Keywords:")
    
    for idx in top_indices:
        print(f"{feature_names[idx]} : {row[idx]:.4f}")
# Out:
# Document 1:
# Artificial intelligence helps machines learn from data and perform smart tasks.
# Top Keywords:
# machines : 0.3713
# perform : 0.3713
# tasks : 0.3713
# smart : 0.3713
# learn : 0.2995
#
# Document 2:
# Machine learning is a part of artificial intelligence that uses algorithms to learn patterns.
# Top Keywords:
# algorithms : 0.4187
# patterns : 0.4187
# artificial : 0.3378
# intelligence : 0.3378
# learn : 0.3378
#
# Document 3:
# Natural language processing helps computers understand human language and text.
# Top Keywords:
# language : 0.6128
# natural : 0.3064
# processing : 0.3064
# text : 0.3064
# understand : 0.3064
#
# Document 4:
# Deep learning uses neural networks for image recognition, speech recognition, and prediction.
# Top Keywords:
# recognition : 0.6003
# deep : 0.3002
# networks : 0.3002
# neural : 0.3002
# image : 0.3002
#
# Document 5:
# Data science combines statistics, programming, and machine learning to analyze data.
# Top Keywords:
# ...
