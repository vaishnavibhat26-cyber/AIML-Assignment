# %%
## ML Idea Generator
## Suggest ML problems in college, healthcare, shopping and describe input → output.
1. College – Student Performance Prediction
Input: attendance, study hours, previous marks
Output: predicted final score or grade

2. College – Attendance Monitoring System
Input: student login data / face recognition
Output: present or absent status

3. Healthcare – Disease Prediction
Input: symptoms, age, medical history
Output: predicted disease

4. Healthcare – Heart Risk Detection
Input: blood pressure, cholesterol, age
Output: risk level (low / medium / high)

5. Shopping – Product Recommendation
Input: user search history, past purchases
Output: recommended products

6. Shopping – Price Prediction
Input: product features, demand, ratings
Output: predicted price.

# %%
ml_ideas = {
    "College": [
        {
            "problem": "Student Performance Prediction",
            "input": "attendance, study hours, previous marks",
            "output": "final score / grade"
        },
        {
            "problem": "Attendance Monitoring",
            "input": "student face image / login data",
            "output": "present or absent"
        }
    ],

    "Healthcare": [
        {
            "problem": "Disease Prediction",
            "input": "symptoms, age, medical history",
            "output": "predicted disease"
        },
        {
            "problem": "Heart Risk Detection",
            "input": "blood pressure, cholesterol, age",
            "output": "risk level"
        }
    ],

    "Shopping": [
        {
            "problem": "Product Recommendation",
            "input": "search history, past purchases",
            "output": "recommended products"
        },
        {
            "problem": "Price Prediction",
            "input": "product features, ratings, demand",
            "output": "predicted price"
        }
    ]
}

for domain, ideas in ml_ideas.items():
    print("\n", domain)
    print("-" * 30)
    
    for i, idea in enumerate(ideas, 1):
        print(f"{i}. Problem : {idea['problem']}")
        print(f"   Input   : {idea['input']}")
        print(f"   Output  : {idea['output']}")
# Out:
#  College
# ------------------------------
# 1. Problem : Student Performance Prediction
#    Input   : attendance, study hours, previous marks
#    Output  : final score / grade
# 2. Problem : Attendance Monitoring
#    Input   : student face image / login data
#    Output  : present or absent
#
#  Healthcare
# ------------------------------
# 1. Problem : Disease Prediction
#    Input   : symptoms, age, medical history
#    Output  : predicted disease
# 2. Problem : Heart Risk Detection
#    Input   : blood pressure, cholesterol, age
#    Output  : risk level
#
#  Shopping
# ------------------------------
# 1. Problem : Product Recommendation
#    Input   : search history, past purchases
#    Output  : recommended products
# 2. Problem : Price Prediction
#    Input   : product features, ratings, demand
#    Output  : predicted price
